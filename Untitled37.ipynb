# %%
from IPython.display import display, HTML

# To display the header
display(HTML('<div style="color: #7b6b59; font-size: 30px; text-align: center;"></div>'))

# For the introduction, you can also do the same:
display(HTML('<div style="padding:20px;color:white;margin:0;font-size:30px;font-family:Georgia;text-align:left;display:fill;border-radius:5px;background-color:#7b6b59;overflow:hidden">Introduction</div>'))
# Out:
# <div style="color: #7b6b59; font-size: 30px; text-align: center;"></div>
# <div style="padding:20px;color:white;margin:0;font-size:30px;font-family:Georgia;text-align:left;display:fill;border-radius:5px;background-color:#7b6b59;overflow:hidden">Introduction</div>

# %%
from IPython.display import display, HTML

# To display the header
display(HTML('<div style="color: #7b6b59; font-size: 30px; text-align: center;"></div>'))

# For the introduction, you can also do the same:
display(HTML('<div style="padding:20px;color:white;margin:0;font-size:30px;font-family:Georgia;text-align:left;display:fill;border-radius:5px;background-color:#7b6b59;overflow:hidden">Import Python Libraries</div>'))
# Out:
# <div style="color: #7b6b59; font-size: 30px; text-align: center;"></div>
# <div style="padding:20px;color:white;margin:0;font-size:30px;font-family:Georgia;text-align:left;display:fill;border-radius:5px;background-color:#7b6b59;overflow:hidden">Import Python Libraries</div>

# %%
from IPython.display import display, HTML

# To display the header
display(HTML('<div style="color: #7b6b59; font-size: 30px; text-align: center;"></div>'))

# For the introduction, you can also do the same:
display(HTML('<div style="padding:20px;color:white;margin:0;font-size:30px;font-family:Georgia;text-align:left;display:fill;border-radius:5px;background-color:#7b6b59;overflow:hidden">Load the Dataset</div>'))
# Out:
# <div style="color: #7b6b59; font-size: 30px; text-align: center;"></div>
# <div style="padding:20px;color:white;margin:0;font-size:30px;font-family:Georgia;text-align:left;display:fill;border-radius:5px;background-color:#7b6b59;overflow:hidden">Load the Dataset</div>

# %%
train_prompts = pd.read_csv("/kaggle/input/llm-detect-ai-generated-text/train_prompts.csv")
train_essays = pd.read_csv("/kaggle/input/llm-detect-ai-generated-text/train_essays.csv")
test_essays = pd.read_csv("/kaggle/input/llm-detect-ai-generated-text/test_essays.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 train_prompts = pd.read_csv("/kaggle/input/llm-detect-ai-generated-text/train_prompts.csv")
#       2 train_essays = pd.read_csv("/kaggle/input/llm-detect-ai-generated-text/train_essays.csv")
#       3 test_essays = pd.read_csv("/kaggle/input/llm-detect-ai-generated-text/test_essays.csv")
#
# NameError: name 'pd' is not defined

# %%
from IPython.display import display, HTML

# To display the header
display(HTML('<div style="color: #7b6b59; font-size: 30px; text-align: center;"></div>'))

# For the introduction, you can also do the same:
display(HTML('<div style="padding:20px;color:white;margin:0;font-size:30px;font-family:Georgia;text-align:left;display:fill;border-radius:5px;background-color:#7b6b59;overflow:hidden">Exploratory Data Analysis</div>'))
# Out:
# <div style="color: #7b6b59; font-size: 30px; text-align: center;"></div>
# <div style="padding:20px;color:white;margin:0;font-size:30px;font-family:Georgia;text-align:left;display:fill;border-radius:5px;background-color:#7b6b59;overflow:hidden">Exploratory Data Analysis</div>

# %%
from IPython.display import display, HTML

# To display the header
display(HTML('<div style="color: #7b6b59; font-size: 30px; text-align: center;"></div>'))

# For the introduction, you can also do the same:
display(HTML('<div style="padding:20px;color:white;margin:0;font-size:30px;font-family:Georgia;text-align:left;display:fill;border-radius:5px;background-color:#7b6b59;overflow:hidden">Standard Approaches: Vectorization and Classic Machine Learning (ML) Model</div>'))
# Out:
# <div style="color: #7b6b59; font-size: 30px; text-align: center;"></div>
# <div style="padding:20px;color:white;margin:0;font-size:30px;font-family:Georgia;text-align:left;display:fill;border-radius:5px;background-color:#7b6b59;overflow:hidden">Standard Approaches: Vectorization and Classic Machine Learning (ML) Model</div>

# %%
from IPython.display import display, HTML

# To display the header
display(HTML('<div style="color: #7b6b59; font-size: 30px; text-align: center;"></div>'))

# For the introduction, you can also do the same:
display(HTML('<div style="padding:20px;color:white;margin:0;font-size:30px;font-family:Georgia;text-align:left;display:fill;border-radius:5px;background-color:#7b6b59;overflow:hidden">Approach 1: Sparse Vectorization and Classic Machine Learning (ML) Model</div>'))
# Out:
# <div style="color: #7b6b59; font-size: 30px; text-align: center;"></div>
# <div style="padding:20px;color:white;margin:0;font-size:30px;font-family:Georgia;text-align:left;display:fill;border-radius:5px;background-color:#7b6b59;overflow:hidden">Approach 1: Sparse Vectorization and Classic Machine Learning (ML) Model</div>

# %%
from IPython.display import display, HTML

# To display the header
display(HTML('<div style="color: #7b6b59; font-size: 30px; text-align: center;"></div>'))

# For the introduction, you can also do the same:
display(HTML('<div style="padding:20px;color:white;margin:0;font-size:30px;font-family:Georgia;text-align:left;display:fill;border-radius:5px;background-color:#7b6b59;overflow:hidden">Approach 1: Sparse Vectorization and Classic Machine Learning (ML) Model</div>'))
