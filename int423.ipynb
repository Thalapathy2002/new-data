# %%
import numpy as np
import matplotlib.pyplot as plt

#Mean 
mu, sigma = 0, 0.1


data = np.random.normal(mu, sigma, 1000)


#Plot the histogram
plt.hist(data, bins=30, density=True, alpha=0.6, color='b')

#Plot the PDF
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = (1/(sigma * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mu) / sigma)**2)


plt.plot(x, p, 'k', linewidth=2)
plt.title("Gaussian Distribution")
plt.show()

# %%
#Example data used here to implement the Guassian distribution

import numpy as np
import matplotlib.pyplot as plt


mu, sigma = 2, 0.4


dt = np.random.normal(mu, sigma, 100)
plt.hist(data, bins=40, density=True, alpha=0.8, color='r')

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100) 

p = (1/(sigma * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mu) / sigma)**2)


plt.plot(x, p, 'k', linewidth=2)
plt.title("Gaussian Distribution")
plt.show()

# %%
#Calculate the Probability Density Function(PDF) You can calculate the PDF for a Gaussian distribution using scipy.stats.norm.

# %%
from scipy.stats import norm

#Mean (mu) and standard deviation (sigma)
mu, sigma = 0, 0.1


#Calculate the probability density at a specific point
x = 0.05
pdf_value = norm.pdf(x, mu, sigma)

print(f"PDF at x={x}: {pdf_value}")
# Out:
# PDF at x=0.05: 3.520653267642995

# %%
from sklearn.mixture import GaussianMixture 
import numpy as np

np.random.seed(0)

# %%
#IMPLEMENTATION OF GAUSSIAN DESTRIBUTION IN MACHINE LEARNING

# %%
Implementation of Gaussian Distribution in Machine Learning 

Consider the famous Iris dataset consisting of 150 samples of iris flowers, each with four features: sepal length, sepal width, petal length, and petal width.
    

We can examine the distribution of one of these features, such as sepal length, using a histogram to see if it approximately follows a Gaussian distribution.
