# %%
import pandas as pd
#Data set loading
wq=pd.read_csv("winequalityRED.csv")
wq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 880 entries, 0 to 879
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   alcohol           880 non-null    float64
#  1   volatile acidity  880 non-null    float64
#  2   sulphates         880 non-null    float64
#  3   citric acid       880 non-null    float64
#  4   density           872 non-null    float64
#  5   chlorides         866 non-null    float64
#  6   quality           880 non-null    int64
# dtypes: float64(6), int64(1)
# memory usage: 48.2 KB

# %%
#checking for the null values
wq.isnull().sum()
f=wq[wq["quality"].isnull()].index.tolist()
print(f)
# Out:
# []

# %%
#replacing missing values with mean values
mean_density = wq["density"].mean()
mean_chlorides = wq["chlorides"].mean()
print("Mean density is", mean_density)
print("Mean chlorides is", mean_chlorides)
# Out:
# Mean density is 0.9968709518348624
# Mean chlorides is 0.0889676674364896

# %%
wq["density"].fillna(value=mean_density, inplace=True)
wq["chlorides"].fillna(value=mean_chlorides, inplace=True)

# %%
#Exporting the dataset
wq.to_csv("clean_file.csv")

# %%
#read the clean dataset
clean_data=pd.read_csv(r"clean_file.csv")

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 880 entries, 0 to 879
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        880 non-null    int64
#  1   alcohol           880 non-null    float64
#  2   volatile acidity  880 non-null    float64
#  3   sulphates         880 non-null    float64
#  4   citric acid       880 non-null    float64
#  5   density           880 non-null    float64
#  6   chlorides         880 non-null    float64
#  7   quality           880 non-null    int64
# dtypes: float64(6), int64(2)
# memory usage: 55.1 KB

# %%
clean_data.columns
# Out:
# Index(['Unnamed: 0', 'alcohol', 'volatile acidity', 'sulphates', 'citric acid',
#        'density', 'chlorides', 'quality'],
#       dtype='object')

# %%
#Calculate correlation select the available features
correlation=clean_data.corr()

# %%
print(correlation)
# Out:
#                   Unnamed: 0   alcohol  volatile acidity  sulphates  \
# Unnamed: 0          1.000000  0.221344         -0.045193  -0.133533
# alcohol             0.221344  1.000000         -0.267341   0.170729
# volatile acidity   -0.045193 -0.267341          1.000000  -0.274257
# sulphates          -0.133533  0.170729         -0.274257   1.000000
# citric acid        -0.129025  0.165989         -0.539905   0.333014
# density            -0.322823 -0.442801          0.048688   0.104882
# chlorides          -0.097756 -0.221227          0.064147   0.399636
# quality             0.093881  0.637385         -0.411480   0.294053
#
#                   citric acid   density  chlorides   quality
# Unnamed: 0          -0.129025 -0.322823  -0.097756  0.093881
# alcohol              0.165989 -0.442801  -0.221227  0.637385
# volatile acidity    -0.539905  0.048688   0.064147 -0.411480
# sulphates            0.333014  0.104882   0.399636  0.294053
# ...

# %%
with pd.option_context("display.precision",2):
    correlation.round(decimals=2).style.background_gradient(cmap="PiYG")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 import pandas as pd
#       2 with pd.option_context("display.precision",2):
# ----> 3     correlation.round(decimals=2).style.background_gradient(cmap="PiYG")
#
# NameError: name 'correlation' is not defined

# %%
import seaborn as sns
import numpy as np
sns.heatmap(correlation, mask=np.zeros_like(correlation, dtype=bool),
            cmap="PiYG", square=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 import seaborn as sns
#       2 import numpy as np
# ----> 3 sns.heatmap(correlation, mask=np.zeros_like(correlation, dtype=bool),
#       4             cmap="PiYG", square=True)
#
# NameError: name 'correlation' is not defined

# %%
#data attributes
#X as features
#Y as target
#Z as major
X=clean_data[["alcohol","volatile acidity", "sulphates", "citric acid", "density", "chlorides"]]
Z=clean_data[["alcohol", "sulphates", "citric acid"]]
Y=clean_data["quality"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.30)
Z_train, Z_test, yz_train, yz_test = train_test_split(Z, Y, test_size=0.30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.30)
#       3 Z_train, Z_test, yz_train, yz_test = train_test_split(Z, Y, test_size=0.30)
#
# NameError: name 'X' is not defined

# %%
from sklearn.tree import DecisionTreeClassifier
d_tree=DecisionTreeClassifier(criterion="entropy", min_samples_split=4)

# %%
d_tree.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 d_tree.fit(X_train,y_train)
#
# NameError: name 'X_train' is not defined

# %%
d_tree2=DecisionTreeClassifier(criterion="entropy", min_samples_split=4)

# %%
d_tree2.fit(Z_train,yz_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 d_tree2.fit(Z_train,yz_train)
#
# NameError: name 'Z_train' is not defined

# %%
from sklearn.metrics import classification_report
quality_prediction_major=d_tree2.predict(Z_test)
#Classification report for the Decision tree with all features
"report for decision tree with all features \n", classification
