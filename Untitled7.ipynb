# %%
print("Naresh Kumar Bachu")
# Out:
# Naresh Kumar Bachu

# %%
import numpy as np
a = np.array([[7,3],[1,2]])
b = np.array([20,9])
c = np.linalg.solve(a,b)
print(c)
# Out:
# [1.18181818 3.90909091]

# %%
import numpy as np
a = np.array([[10,-5],[4,2]])
b = np.array([35,10])
c = np.linalg.solve(a,b)
print(c)
# Out:
# [ 3. -1.]
