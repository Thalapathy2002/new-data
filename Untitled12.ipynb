# %%
import pandas as pd

data = {'A': ['Temp', 'Humidity', 'windy', 'playgolf'],
        'B': ['high', 'normal', 'high', 'yes']}
df = pd.DataFrame(data)

print("Original dataframe:")
print(df)
# Out:
# Original dataframe:
#           A       B
# 0      Temp    high
# 1  Humidity  normal
# 2     windy    high
# 3  playgolf     yes
