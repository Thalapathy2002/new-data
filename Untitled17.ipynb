# %%
class FuzzySet:
    def __init__(self, name, membership_function):
        self.name = name
        self.membership_function = membership_function
    
    def membership_degree(self, x):
        return self.membership_function(x)

# Example of a fuzzy set representing "tall" people
def tall_membership(x):
    if x >= 170 and x <= 190:
        return 1.0  # Fully tall
    elif x > 150 and x < 170:
        return (x - 150) / (170 - 150)  # Partially tall
    elif x >= 190 and x <= 210:
        return (210 - x) / (210 - 190)  # Partially tall
    else:
        return 0.0  # Not tall

tall_set = FuzzySet("Tall", tall_membership)

# %%
class FIzzySet:
    def __init__(self, name, membership_function):
    self.name = name
    self.membership_function = membership_function
    
    
    def membership_degree(self, x):
        return self.membership_function(x)
    
    
    #Example of a fuzzy set representing "tall" people
    def tall_membership(x):
        if x >= 170 and x <= 190:
            return 1.0 #Fully tall
        elif x > 150 and x < 170:
            return(x - 150)/(170 - 150) #Partially tall
        elif x >=190 and x <= 210:
            return(210 - x)/(210 - 190) #Partially tall
        else:
            return 0.0 #Not tall
        
        
    tall_set = FuzzySet("Tall", tall_membership)
# Out:
#   Cell In[7], line 3
#     self.name = NameError
#     ^
# IndentationError: expected an indented block after function definition on line 2

# %%
class FuzzySet:
    def __init__(self, name, membership_function):
        self.name = name
        self.membership_function = membership_function
    
    def membership_degree(self, x):
        return self.membership_function(x)

# Example of a fuzzy set representing "tall" people
def tall_membership(x):
    if x >= 170 and x <= 190:
        return 1.0  # Fully tall
    elif x > 150 and x < 170:
        return (x - 150) / (170 - 150)  # Partially tall
    elif x >= 190 and x <= 210:
        return (210 - x) / (210 - 190)  # Partially tall
    else:
        return 0.0  # Not tall

tall_set = FuzzySet("Tall", tall_membership)
#Test the membership degree for a person with height 180
print("Membership degree of a person with height 180 in the Tall set:", tall_set.membership_degree(160))
# Out:
# Membership degree of a person with height 180 in the Tall set: 0.5

# %%
#Write a Python program to represent a class fuzzy set to check certain degree range or temperature
