# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import IsolationForest
import matplotlib.pyplot as plt

# %%
# Generating a synthetic dataset
np.random.seed(42)

# Normal data points
X_normal = 0.3 * np.random.randn(100, 2)
X_normal = np.r_[X_normal + 2, X_normal - 2]

# Anamalous data points

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
from sklearn.datasets import make_blobs
from scipy.cluster.hierarchy import dendrogram, linkage

# For visualization
import seaborn as sns
sns.set()

# %%
X, y = make_blobs(n_samples=100, centers=3, random_state=42, cluster_std=1.5)


plt.scatter(X[:, 0], X[:, 1], c='blue', marker='o', edgecolor='black', s=5)
plt.title("Sample Data")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# %%
import nupmy as np
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativelyClustering
from scipy.cluster.hierarchy import dendrogram, linkage


X = np.array([[1, 2], [2, 3], [3, 3], [5, 5], [8, 8], [1, 0], [0, 1], [9, 9]])
