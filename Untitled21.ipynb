# %%
'''if a and b are two fuzzy sets with membership functions mueA(x) = {0.2, 0.5, 0.6, 0.1, 0.9} mueB(x) = {0.1, 0.5, 0.2. 0.7, 0.8} Then the value of mueA intersection B.'''

# %%
To find the intersection of two fuzzy sets 
�
A and 
�
B, denoted by 
�
∩
�
A∩B, we need to take the minimum of the membership values of each corresponding pair of elements from the two sets.

Given the membership functions:

�
�
(
�
)
=
{
0.2
,
0.5
,
0.6
,
0.1
,
0.9
}
μ 
A
​
 (x)={0.2,0.5,0.6,0.1,0.9}
�
�
(
�
)
=
{
0.1
,
0.5
,
0.2
,
0.7
,
0.8
}
μ 
B
​
 (x)={0.1,0.5,0.2,0.7,0.8}

We can find the intersection 
�
�
∩
�
(
�
)
μ 
A∩B
​
 (x) by taking the minimum of corresponding values:

�
�
∩
�
(
�
)
=
min
⁡
(
�
�
(
�
)
,
�
�
(
�
)
)
μ 
A∩B
​
 (x)=min(μ 
A
​
 (x),μ 
B
​
 (x))

So, the resulting membership function for the intersection 
�
∩
�
A∩B is:

�
�
∩
�
(
�
)
=
{
min
⁡
(
0.2
,
0.1
)
,
min
⁡
(
0.5
,
0.5
)
,
min
⁡
(
0.6
,
0.2
)
,
min
⁡
(
0.1
,
0.7
)
,
min
⁡
(
0.9
,
0.8
)
}
μ 
A∩B
​
 (x)={min(0.2,0.1),min(0.5,0.5),min(0.6,0.2),min(0.1,0.7),min(0.9,0.8)}

�
�
∩
�
(
�
)
=
{
0.1
,
0.5
,
0.2
,
0.1
,
0.8
}
μ 
A∩B
​
 (x)={0.1,0.5,0.2,0.1,0.8}

Therefore, 
�
�
∩
�
(
�
)
=
{
0.1
,
0.5
,
0.2
,
0.1
,
0.8
}
μ 
A∩B
​
 (x)={0.1,0.5,0.2,0.1,0.8}.
